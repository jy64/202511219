# %%
def greet(msg):
    print("in greet:", msg)
    return msg + "!"

print(greet("안녕"))


def greet(msg: str) -> str:
    print("in greet:", msg)
    return msg + "!"

print(greet("안녕"))
greet(3.141592)
# Out:
# in greet: 안녕
# 안녕!
# in greet: 안녕
# 안녕!
# in greet: 3.141592
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       9     print("in greet:", msg)
#      10     return msg + "!"
#      11
#      12 print(greet("안녕"))
# ---> 13 greet(3.141592)
#
# Cell In[1], line 10, in greet(msg)
#       8 def greet(msg: str) -> str:
#       9     print("in greet:", msg)
# ---> 10     return msg + "!"
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
