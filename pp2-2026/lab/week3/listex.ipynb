# %% [markdown]
# list 연습 노트 파일입니다.

# %% [markdown]
# 리스트의 합병 연산 (+)
# 리스트의 곱 연산 (*)

# %%
print("hello, world")
# Out:
# hello, world

# %%
fruit1 = ["사과", "바나나"]
fruit2 = ["복숭아", "포도"]
print(fruit1)
# Out:
# ['사과', '바나나']

# %%
fruit1 = ["사과", "바나나"]
fruit2 = ["복숭아", "포도"]
fruits = fruit1 + fruit2
print(fruits)
# Out:
# ['사과', '바나나', '복숭아', '포도']

# %%
temps = [28, 31, 33, 35, 27, 26, 25]
values =temps

values[3]
print(values)
print(temps)
# Out:
# [28, 31, 33, 35, 27, 26, 25]
# [28, 31, 33, 35, 27, 26, 25]
